# %% [markdown]
# "I'm Stephen Cauley..."
#
# "How many of you have actually done the introductory project? Hmmm... Interesting..."

# %% [markdown]
# Keep in mind:
# - ($40$ % code?)
# - ($50$ % theory)
# - ($\pm 10$% excellence)

# %% [markdown]
# ...*talks boring anecdotes for 10 minutes, but at least he's peppering in some 6/10 humour*...

# %% [markdown]
# Show graphically that the equation only has one root
#
# $$  2x - 3 \sin x + 5 = 0 $$

# %% [markdown]
# **PUT ALL THE CODE AT THE END**

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import numpy as np

# %%
x = np.linspace(-4,-1,100)
y = 2*x + 5
y1 = 3*np.sin(x)

# %%
plt.plot(x,y)
plt.plot(x,y1)

# %%
# %%tikz
# \draw [->] (-2.5, 0) -- (2.5, 0) node [right] {$x$};
# \draw [->] (0, -0.5) -- (0, 2) node [above] {$V$};
# \draw [mred, semithick, dashed] (-1.5, 0) node [below] {$-a$} -- (-1.5, 2);
# \draw [mred, semithick, dashed] (1.5, 0) node [below] {$a$} -- (1.5, 2);
# \draw [mred, semithick] (-1.5, 0) -- (1.5, 0);
# Out:
# LaTeX terminated with signal -255
# This is pdfTeX, Version 3.14159265-2.6-1.40.17 (MiKTeX 2.9.6100 64-bit) (preloaded format=pdflatex 2017.1.3)  17 OCT 2017 12:35
# entering extended mode
# **./tikz.tex
# (tikz.tex
# LaTeX2e <2016/03/31> patch level 3
# Babel <3.9r> and hyphenation patterns for 75 language(s) loaded.
# ("C:\Program Files\MiKTeX 2.9\tex\latex\standalone\standalone.cls"
# Document Class: standalone 2015/07/15 v1.2 Class to compile TeX sub-files stand
# alone
# ("C:\Program Files\MiKTeX 2.9\tex\generic\oberdiek\ifluatex.sty"
# Package: ifluatex 2016/05/16 v1.4 Provides the ifluatex switch (HO)
# Package ifluatex Info: LuaTeX not detected.
# )
# ("C:\Program Files\MiKTeX 2.9\tex\generic\oberdiek\ifpdf.sty"
# Package: ifpdf 2016/05/14 v3.1 Provides the ifpdf switch
# )
# ("C:\Program Files\MiKTeX 2.9\tex\generic\ifxetex\ifxetex.sty"
# Package: ifxetex 2010/09/12 v0.6 Provides ifxetex conditional
# )
# ("C:\Program Files\MiKTeX 2.9\tex\latex\xkeyval\xkeyval.sty"
# ...

# %%
# %tikz \draw (0,0) rectangle (1,1);
# Out:
# No image generated.

# %%
# !pip install git+git://github.com/mkrphys/ipython-tikzmagic.git
# Out:
# ...
#   Cloning git://github.com/mkrphys/ipython-tikzmagic.git to c:\users\cturn\appdata\local\temp\pip-8tsvs035-build
# ...
#   Running setup.py install for ipython-tikzmagic: started
#     Running setup.py install for ipython-tikzmagic: finished with status 'done'
# ...

# %%
# %load_ext tikzmagic

# %%
# !pip install ImageMagick
# Out:
# ...
#   Could not find a version that satisfies the requirement ImageMagick (from versions: )
# No matching distribution found for ImageMagick
